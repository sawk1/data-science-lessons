# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x=[1, 2, 3, 4, 5, 6, 7]
y=[3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
import numpy as np
t=np.linspace(0,10,51)
f=np.cos(t)
plt.plot(t,f)
plt.title('График f(t)')
plt.xlabel('Значения t')
plt.ylabel('Значения f')
# Out:
# Text(0, 0.5, 'Значения f')

# %%
x=np.linspace(-3,3,51)
y1=x**2
y2=2 * x + 0.5
y3 = -3 * x - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()

fig.set_size_inches(8, 6)
fig.subplots_adjust(wspace=0.3, hspace=0.3)

ax1.plot(x,y1)
ax1.set_title('График y1')
ax1.set_xlim([-5, 5])

ax2.plot(x,y2)
ax2.set_title('График y2')

ax3.plot(x,y3)
ax3.set_title('График y3')

ax4.plot(x,y4)
ax4.set_title('График y4')
# Out:
# Text(0.5, 1.0, 'График y4')

# %%
import pandas as pd
plt.style.use('fivethirtyeight')
credit_card = pd.read_csv('creditcard.csv')
credit_card['Class'].value_counts().plot(kind='bar')
plt.show()

# %%
credit_card['Class'].value_counts().plot(kind='bar',logy=True)
plt.show()

# %%
credit_card.loc[credit_card['Class']==1, 'V1'].value_counts().hist(bins=20)

plt.show()

# %%
credit_card.loc[credit_card['Class']==0, 'V1'].value_counts().hist(bins=20)

plt.show()
